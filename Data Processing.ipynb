# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 3A4D-13C4
#
#  Directory of C:\Users\Adrika Banerjee\OneDrive\Desktop\Dataset walkthrough
#
# 31-07-2025  18:26    <DIR>          .
# 31-07-2025  18:11    <DIR>          ..
# 31-07-2025  18:26    <DIR>          .ipynb_checkpoints
# 31-07-2025  18:26               337 Data Processing.ipynb
# 31-07-2025  15:09       676,464,870 Google-Playstore.csv
# 31-07-2025  16:39            33,849 Untitled.ipynb
#                3 File(s)    676,499,056 bytes
#                3 Dir(s)  390,340,968,448 bytes free

# %%
import pandas as pd

# %%
data = pd.read_csv("Google-Playstore.csv")

# %%
data.head(10)
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
# 5                                             IMOCCI
# 6                   unlimited 4G data prank free app
# 7                              The Everyday Calendar
# 8                                          WhatsOpen
# 9                   Neon 3d Iron Tech Keyboard Theme
#
#                                           App Id          Category  Rating  \
# 0                            com.ishakwe.gakondo         Adventure     0.0
# 1                     com.webserveis.batteryinfo             Tools     4.4
# 2                           com.doantiepvien.crm      Productivity     0.0
# 3                        cst.stJoseph.ug17ucs548     Communication     5.0
# ...

# %%
data['App Name']
# Out:
# 0                                                    Gakondo
# 1                                        Ampere Battery Info
# 2                                                     Vibook
# 3          Smart City Trichy Public Service Vehicles 17UC...
# 4                                                    GROW.me
#                                  ...
# 2312939                                             大俠客—熱血歸來
# 2312940                                           ORU Online
# 2312941                                       Data Structure
# 2312942                                          Devi Suktam
# 2312943                         Biliyor Musun - Sonsuz Yarış
# Name: App Name, Length: 2312944, dtype: object

# %%
data.isnull().sum()
# Out:
# App Name                  5
# App Id                    0
# Category                  0
# Rating                22883
# Rating Count          22883
# Installs                107
# Minimum Installs        107
# Maximum Installs          0
# Free                      0
# Price                     0
# Currency                135
# Size                    196
# Minimum Android        6530
# Developer Id             33
# Developer Website    760835
# Developer Email          31
# Released              71053
# Last Updated              0
# Content Rating            0
# Privacy Policy       420953
# Ad Supported              0
# In App Purchases          0
# Editors Choice            0
# Scraped Time              0
# dtype: int64

# %%
data
# Out:
#                                                   App Name  \
# 0                                                  Gakondo
# 1                                      Ampere Battery Info
# 2                                                   Vibook
# 3        Smart City Trichy Public Service Vehicles 17UC...
# 4                                                  GROW.me
# ...                                                    ...
# 2312939                                           大俠客—熱血歸來
# 2312940                                         ORU Online
# 2312941                                     Data Structure
# 2312942                                        Devi Suktam
# 2312943                       Biliyor Musun - Sonsuz Yarış
#
#                                        App Id       Category  Rating  \
# 0                         com.ishakwe.gakondo      Adventure     0.0
# 1                  com.webserveis.batteryinfo          Tools     4.4
# ...

# %%
df=data.dropna()
# Out:
#                                  App Name  \
# 0                                 Gakondo
# 1                     Ampere Battery Info
# 4                                 GROW.me
# 5                                  IMOCCI
# 9        Neon 3d Iron Tech Keyboard Theme
# ...                                   ...
# 2312933    Caustic Editor for VolcaSample
# 2312934   Vietnamese - English Translator
# 2312938       Lero TOEFL Recorder + Timer
# 2312940                        ORU Online
# 2312942                       Devi Suktam
#
#                                           App Id         Category  Rating  \
# 0                            com.ishakwe.gakondo        Adventure     0.0
# 1                     com.webserveis.batteryinfo            Tools     4.4
# 4                           com.horodyski.grower            Tools     0.0
# 5                                     com.imocci           Social     0.0
# 9          com.ikeyboard.theme.neon_3d.iron.tech  Personalization     4.7
# ...

# %%
2312944 - 1287191
# Out:
# 1025753

# %%
df.isnull().sum()
# Out:
# App Name             0
# App Id               0
# Category             0
# Rating               0
# Rating Count         0
# Installs             0
# Minimum Installs     0
# Maximum Installs     0
# Free                 0
# Price                0
# Currency             0
# Size                 0
# Minimum Android      0
# Developer Id         0
# Developer Website    0
# Developer Email      0
# Released             0
# Last Updated         0
# Content Rating       0
# Privacy Policy       0
# Ad Supported         0
# In App Purchases     0
# Editors Choice       0
# Scraped Time         0
# dtype: int64
